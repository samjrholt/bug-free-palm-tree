# %% [markdown]
# # mag2exp: DC magnetometry
#
# This notebook is designed to go with the ______ paper and showcase the code and the techniques that `mag2exp` included in the paper.

# %%
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# Import packages

# %%
import discretisedfield as df
import micromagneticmodel as mm
import oommfc as oc
import numpy as np
from tqdm import tqdm
import mag2exp
import micromagneticdata as mmd
import matplotlib.pyplot as plt
import matplotlib
plt.style.use('default')

# %% [markdown]
# Define the energy terms of the micromagnetic simulation.

# %%
system = mm.System(name="DC_simulation")

H_max = 3/mm.consts.mu0 # 3 T
angle = 3 *np.pi/180  # Missalign the applied field by 1 degree to break symmtry.
system.energy = (mm.Exchange(A=1.6e-11)
                 + mm.DMI(D=4e-3, crystalclass='T')
                 + mm.UniaxialAnisotropy(K=5.1e5, u=(0, 0, 1))
                 + mm.Demag()
                 + mm.Zeeman(H=(0, H_max*np.sin(angle), H_max*np.cos(angle))))
system.energy
# Out:
# Exchange(A=1.6e-11) + DMI(D=0.004, crystalclass='T') + UniaxialAnisotropy(K=510000.0, u=(0, 0, 1)) + Demag() + Zeeman(H=(0, 124942.89206258474, 2384052.401606252))

# %% [markdown]
# Define the initial magnetisation

# %%
Ms = 1.1e6  # A/m
region = df.Region(p1=(-150e-9, -150e-9, -20e-9), p2=(150e-9, 150e-9, 0))
mesh = df.Mesh(region=region, cell=(5e-9, 5e-9, 5e-9))
system.m = df.Field(mesh, dim=3, value=(0, 0, 1), norm=Ms)
system.m.plane('z').z.mpl()

# %% [markdown]
# Minimise the energy

# %%
md = oc.MinDriver()
md.drive(system)

# Plot relaxed configuration: vectors in z-plane
system.m.plane('z').mpl()
# Out:
# Running OOMMF (ExeOOMMFRunner)[2022/07/15 08:31]... (0.5 s)

# %% [markdown]
# ## DC Magnetometry
# Perform a hysteresis measurment starting from the saturated state.

# %% [markdown]
# Short plotting functions

# %%
matplotlib.rcParams.update({'font.size': 15})
def plot_hysteresis():
    fig, ax = plt.subplots(figsize=(7,5))
    ax.grid(zorder=0)
    ax.scatter(np.array(H_values[:steps])*mm.consts.mu0, np.array(mag_list)[:steps,2]/Ms, label='Down Sweep', zorder=2)
    ax.scatter(np.array(H_values[steps:])*mm.consts.mu0, np.array(mag_list)[steps:,2]/Ms, label='Up Sweep', zorder=1)
    ax.scatter(np.array(H_values[47])*mm.consts.mu0, np.array(mag_list)[47,2]/Ms, marker='D', c='k', zorder=3)
    ax.legend()
    ax.set_ylabel(r'$M_z$ (Ms)')
    ax.set_xlabel('Applied field (T)')
    plt.show()
    
def plot_magnetisation(H):
    fig, ax = plt.subplots(figsize=(6,7))
    idx = 47
    sweep_data = mmd.Data(system.name)
    sweep_data[idx].m0.orientation.plane('z').z.mpl.scalar(ax=ax, cmap='coolwarm', clim=(-1,1), colorbar_label=r'$M_z$ (Ms)', interpolation='spline16',)
    sweep_data[idx].m0.orientation.plane('z', n=(20,20)).mpl.vector(ax=ax, use_color=False, scale=20, headwidth=6, width=0.004)
    ax.set_title(f'Magnetisation at {H_values[idx]*mm.consts.mu0:.2f} T\n on down sweep')
    fig.tight_layout()
    plt.show()

# %% [markdown]
# Parameters for the DC applied field.

# %%
steps = 100

H_values = np.concatenate([np.linspace(H_max, -H_max, steps), np.linspace(-H_max, H_max, steps)])

# %%
mag_list = []
for H in H_values:
    system.energy.zeeman.H = (0, H*np.sin(angle), H*np.cos(angle))
    md.drive(system, verbose=0)
    mag_list.append(mag2exp.magnetometry.magnetisation(system.m))

plot_hysteresis()  # Use matplotlib to plot

# %%
plot_magnetisation(0.15)  # Use matplotlib to plot
